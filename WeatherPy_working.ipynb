# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 595

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
base_url = 'https://api.openweathermap.org/data/2.5/weather'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'{base_url}?q={city}&appid={weather_api_key}&units=imperial'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1


    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta cardon
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | korla
# Processing Record 5 of Set 1 | matay
# Processing Record 6 of Set 1 | fez
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 1 | derzhavinsk
# Processing Record 11 of Set 1 | deputatskiy
# Processing Record 12 of Set 1 | oyem
# Processing Record 13 of Set 1 | ixtapa
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | lebu
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 18 of Set 1 | lahaina
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | nemuro
# Processing Record 22 of Set 1 | naze
# Processing Record 23 of Set 1 | olafsvik
# Processing Record 24 of Set 1 | tiksi
# Processing Record 25 of Set 1 | nikolskoye
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | ribeira grande
# Processing Record 28 of Set 1 | havre-saint-pierre
# Processing Record 29 of Set 1 | klaksvik
# Processing Record 30 of Set 1 | dingle
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | emerald
# Processing Record 33 of Set 1 | srednekolymsk
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | pindiga
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | bengkulu
# Processing Record 39 of Set 1 | ostrovnoy
# Processing Record 40 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 1 | balakhninskiy
# Processing Record 42 of Set 1 | walvis bay
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | mayahi
# Processing Record 45 of Set 1 | guerrero negro
# Processing Record 46 of Set 1 | aklavik
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | yulara
# Processing Record 49 of Set 1 | ankang
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 0 of Set 2 | mahadday weyne
# City not found. Skipping...
# Processing Record 1 of Set 2 | pevek
# Processing Record 2 of Set 2 | meulaboh
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | chokurdakh
# Processing Record 6 of Set 2 | port blair
# Processing Record 7 of Set 2 | itaituba
# Processing Record 8 of Set 2 | nantucket
# Processing Record 9 of Set 2 | big rapids
# Processing Record 10 of Set 2 | te anau
# Processing Record 11 of Set 2 | kaeo
# Processing Record 12 of Set 2 | merauke
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | ust-maya
# Processing Record 15 of Set 2 | ilulissat
# Processing Record 16 of Set 2 | kesova gora
# Processing Record 17 of Set 2 | huarmey
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | acajutla
# Processing Record 20 of Set 2 | okhotsk
# Processing Record 21 of Set 2 | ahipara
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | punta gorda
# Processing Record 25 of Set 2 | husavik
# Processing Record 26 of Set 2 | scarborough
# Processing Record 27 of Set 2 | umm kaddadah
# Processing Record 28 of Set 2 | teguldet
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | trairi
# Processing Record 31 of Set 2 | moron
# Processing Record 32 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 2 | atuona
# Processing Record 34 of Set 2 | avarua
# Processing Record 35 of Set 2 | severo-zadonsk
# Processing Record 36 of Set 2 | val-david
# Processing Record 37 of Set 2 | chatellerault
# Processing Record 38 of Set 2 | tuatapere
# Processing Record 39 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 40 of Set 2 | tuktoyaktuk
# Processing Record 41 of Set 2 | lorengau
# Processing Record 42 of Set 2 | shingu
# Processing Record 43 of Set 2 | kurilsk
# Processing Record 44 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 2 | vaini
# Processing Record 46 of Set 2 | vestmannaeyjar
# Processing Record 47 of Set 2 | vila velha
# Processing Record 48 of Set 2 | georgetown
# Processing Record 49 of Set 2 | luanda
# Processing Record 0 of Set 3 | taunsa
# Processing Record 1 of Set 3 | ulety
# Processing Record 2 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 3 | sitka
# Processing Record 4 of Set 3 | new norfolk
# Processing Record 5 of Set 3 | benidorm
# Processing Record 6 of Set 3 | qaanaaq
# Processing Record 7 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 3 | mandal
# Processing Record 9 of Set 3 | porto novo
# Processing Record 10 of Set 3 | inuvik
# Processing Record 11 of Set 3 | caravelas
# Processing Record 12 of Set 3 | saint-philippe
# Processing Record 13 of Set 3 | campina verde
# Processing Record 14 of Set 3 | luderitz
# Processing Record 15 of Set 3 | hobart
# Processing Record 16 of Set 3 | aguimes
# Processing Record 17 of Set 3 | kavaratti
# Processing Record 18 of Set 3 | tabou
# Processing Record 19 of Set 3 | faya
# Processing Record 20 of Set 3 | vestmanna
# Processing Record 21 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 3 | kavieng
# Processing Record 23 of Set 3 | liwale
# Processing Record 24 of Set 3 | bethel
# Processing Record 25 of Set 3 | witu
# Processing Record 26 of Set 3 | alekseyevsk
# Processing Record 27 of Set 3 | garh maharaja
# Processing Record 28 of Set 3 | kargopol
# Processing Record 29 of Set 3 | khani
# Processing Record 30 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 3 | sao caetano de odivelas
# Processing Record 32 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 3 | saint-joseph
# Processing Record 34 of Set 3 | gangotri
# City not found. Skipping...
# Processing Record 35 of Set 3 | ancud
# Processing Record 36 of Set 3 | hermanus
# Processing Record 37 of Set 3 | pisco
# Processing Record 38 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 3 | sola
# Processing Record 40 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 3 | burica
# City not found. Skipping...
# Processing Record 42 of Set 3 | nogliki
# Processing Record 43 of Set 3 | saldanha
# Processing Record 44 of Set 3 | dongzhen
# Processing Record 45 of Set 3 | trinidad
# Processing Record 46 of Set 3 | castro
# Processing Record 47 of Set 3 | alytus
# Processing Record 48 of Set 3 | evensk
# Processing Record 49 of Set 3 | ojinaga
# Processing Record 0 of Set 4 | ponta do sol
# Processing Record 1 of Set 4 | bambous virieux
# Processing Record 2 of Set 4 | ozinki
# Processing Record 3 of Set 4 | yuncheng
# Processing Record 4 of Set 4 | puerto ayora
# Processing Record 5 of Set 4 | akureyri
# Processing Record 6 of Set 4 | upernavik
# Processing Record 7 of Set 4 | kidal
# Processing Record 8 of Set 4 | pantai remis
# Processing Record 9 of Set 4 | tautira
# Processing Record 10 of Set 4 | samarai
# Processing Record 11 of Set 4 | lagoa
# Processing Record 12 of Set 4 | olinda
# Processing Record 13 of Set 4 | zhangjiakou
# Processing Record 14 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 4 | bandarbeyla
# Processing Record 16 of Set 4 | polazna
# Processing Record 17 of Set 4 | nhamunda
# Processing Record 18 of Set 4 | krynychky
# Processing Record 19 of Set 4 | kruisfontein
# Processing Record 20 of Set 4 | yumen
# Processing Record 21 of Set 4 | anadyr
# Processing Record 22 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 4 | lavrentiya
# Processing Record 24 of Set 4 | tazovskiy
# Processing Record 25 of Set 4 | ikungi
# Processing Record 26 of Set 4 | carnarvon
# Processing Record 27 of Set 4 | mar del plata
# Processing Record 28 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 29 of Set 4 | hida
# Processing Record 30 of Set 4 | katsuura
# Processing Record 31 of Set 4 | mahebourg
# Processing Record 32 of Set 4 | phonhong
# Processing Record 33 of Set 4 | sao filipe
# Processing Record 34 of Set 4 | bodden town
# Processing Record 35 of Set 4 | port lincoln
# Processing Record 36 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 4 | provideniya
# Processing Record 38 of Set 4 | kamaishi
# Processing Record 39 of Set 4 | souillac
# Processing Record 40 of Set 4 | mesagne
# Processing Record 41 of Set 4 | belyy yar
# Processing Record 42 of Set 4 | yar-sale
# Processing Record 43 of Set 4 | acari
# Processing Record 44 of Set 4 | esperance
# Processing Record 45 of Set 4 | santa maria
# Processing Record 46 of Set 4 | geraldton
# Processing Record 47 of Set 4 | cidreira
# Processing Record 48 of Set 4 | dikson
# Processing Record 49 of Set 4 | mwanza
# Processing Record 0 of Set 5 | komsomolskiy
# Processing Record 1 of Set 5 | cherskiy
# Processing Record 2 of Set 5 | saint george
# Processing Record 3 of Set 5 | orumiyeh
# Processing Record 4 of Set 5 | leningradskiy
# Processing Record 5 of Set 5 | constitucion
# Processing Record 6 of Set 5 | buala
# Processing Record 7 of Set 5 | tateyama
# Processing Record 8 of Set 5 | qiongshan
# Processing Record 9 of Set 5 | kanniyakumari
# Processing Record 10 of Set 5 | maniitsoq
# Processing Record 11 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 5 | ahuimanu
# Processing Record 13 of Set 5 | tawzar
# City not found. Skipping...
# Processing Record 14 of Set 5 | bouca
# Processing Record 15 of Set 5 | chuy
# Processing Record 16 of Set 5 | kerema
# Processing Record 17 of Set 5 | abu zabad
# Processing Record 18 of Set 5 | port elizabeth
# Processing Record 19 of Set 5 | pangody
# Processing Record 20 of Set 5 | pachino
# Processing Record 21 of Set 5 | xian
# Processing Record 22 of Set 5 | mocajuba
# Processing Record 23 of Set 5 | yaan
# Processing Record 24 of Set 5 | victoria
# Processing Record 25 of Set 5 | hasaki
# Processing Record 26 of Set 5 | honningsvag
# Processing Record 27 of Set 5 | turukhansk
# Processing Record 28 of Set 5 | nam tha
# City not found. Skipping...
# Processing Record 29 of Set 5 | coihaique
# Processing Record 30 of Set 5 | bressanone
# Processing Record 31 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 5 | mount gambier
# Processing Record 33 of Set 5 | norman wells
# Processing Record 34 of Set 5 | hithadhoo
# Processing Record 35 of Set 5 | palomares
# Processing Record 36 of Set 5 | half moon bay
# Processing Record 37 of Set 5 | khatanga
# Processing Record 38 of Set 5 | kaitangata
# Processing Record 39 of Set 5 | vostok
# Processing Record 40 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 5 | sao joao de pirabas
# Processing Record 42 of Set 5 | dunhua
# Processing Record 43 of Set 5 | sakakah
# Processing Record 44 of Set 5 | tuban
# Processing Record 45 of Set 5 | mantua
# Processing Record 46 of Set 5 | vanimo
# Processing Record 47 of Set 5 | roma
# Processing Record 48 of Set 5 | lompoc
# Processing Record 49 of Set 5 | praia da vitoria
# Processing Record 0 of Set 6 | hofn
# Processing Record 1 of Set 6 | broome
# Processing Record 2 of Set 6 | kahului
# Processing Record 3 of Set 6 | ponta delgada
# Processing Record 4 of Set 6 | zolotinka
# City not found. Skipping...
# Processing Record 5 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 6 | maturin
# Processing Record 7 of Set 6 | matto
# City not found. Skipping...
# Processing Record 8 of Set 6 | razole
# Processing Record 9 of Set 6 | mosquera
# Processing Record 10 of Set 6 | pangnirtung
# Processing Record 11 of Set 6 | taunggyi
# Processing Record 12 of Set 6 | hay river
# Processing Record 13 of Set 6 | atar
# Processing Record 14 of Set 6 | adrar
# Processing Record 15 of Set 6 | bundibugyo
# Processing Record 16 of Set 6 | dunedin
# Processing Record 17 of Set 6 | north bend
# Processing Record 18 of Set 6 | goderich
# Processing Record 19 of Set 6 | port hueneme
# Processing Record 20 of Set 6 | belaya gora
# Processing Record 21 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 6 | saskylakh
# Processing Record 23 of Set 6 | laurel
# Processing Record 24 of Set 6 | safaga
# Processing Record 25 of Set 6 | chimore
# Processing Record 26 of Set 6 | mana
# Processing Record 27 of Set 6 | the valley
# Processing Record 28 of Set 6 | prince rupert
# Processing Record 29 of Set 6 | fort nelson
# Processing Record 30 of Set 6 | qaqortoq
# Processing Record 31 of Set 6 | babu
# Processing Record 32 of Set 6 | los llanos de aridane
# Processing Record 33 of Set 6 | hanford
# Processing Record 34 of Set 6 | santa fe
# Processing Record 35 of Set 6 | namibe
# Processing Record 36 of Set 6 | thompson
# Processing Record 37 of Set 6 | asyut
# Processing Record 38 of Set 6 | zhuhai
# Processing Record 39 of Set 6 | hobyo
# Processing Record 40 of Set 6 | thinadhoo
# Processing Record 41 of Set 6 | keetmanshoop
# Processing Record 42 of Set 6 | san patricio
# Processing Record 43 of Set 6 | karakendzha
# City not found. Skipping...
# Processing Record 44 of Set 6 | hamilton
# Processing Record 45 of Set 6 | zhangye
# Processing Record 46 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 6 | paamiut
# Processing Record 48 of Set 6 | yueyang
# Processing Record 49 of Set 6 | tuy hoa
# Processing Record 0 of Set 7 | comodoro rivadavia
# Processing Record 1 of Set 7 | iqaluit
# Processing Record 2 of Set 7 | sharya
# Processing Record 3 of Set 7 | nanortalik
# Processing Record 4 of Set 7 | tornio
# Processing Record 5 of Set 7 | pokhara
# Processing Record 6 of Set 7 | torbay
# Processing Record 7 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 8 of Set 7 | cheyenne
# Processing Record 9 of Set 7 | westport
# Processing Record 10 of Set 7 | nieuw amsterdam
# Processing Record 11 of Set 7 | socuellamos
# Processing Record 12 of Set 7 | lamar
# Processing Record 13 of Set 7 | sao joao da barra
# Processing Record 14 of Set 7 | ketchikan
# Processing Record 15 of Set 7 | russell
# Processing Record 16 of Set 7 | eucaliptus
# Processing Record 17 of Set 7 | talnakh
# Processing Record 18 of Set 7 | banda aceh
# Processing Record 19 of Set 7 | puri
# Processing Record 20 of Set 7 | douentza
# Processing Record 21 of Set 7 | lunca ilvei
# Processing Record 22 of Set 7 | sangod
# Processing Record 23 of Set 7 | morro bay
# Processing Record 24 of Set 7 | havelock
# Processing Record 25 of Set 7 | muros
# Processing Record 26 of Set 7 | matara
# Processing Record 27 of Set 7 | wenling
# Processing Record 28 of Set 7 | puerto barrios
# Processing Record 29 of Set 7 | samandag
# Processing Record 30 of Set 7 | ewa beach
# Processing Record 31 of Set 7 | alexandria
# Processing Record 32 of Set 7 | monteiro
# Processing Record 33 of Set 7 | rio grande
# Processing Record 34 of Set 7 | punta
# Processing Record 35 of Set 7 | san cristobal
# Processing Record 36 of Set 7 | tual
# Processing Record 37 of Set 7 | high level
# Processing Record 38 of Set 7 | la maddalena
# Processing Record 39 of Set 7 | tutoia
# Processing Record 40 of Set 7 | faanui
# Processing Record 41 of Set 7 | veraval
# Processing Record 42 of Set 7 | mamlyutka
# Processing Record 43 of Set 7 | gardelegen
# Processing Record 44 of Set 7 | narsaq
# Processing Record 45 of Set 7 | rorvik
# Processing Record 46 of Set 7 | chernyshevskiy
# Processing Record 47 of Set 7 | shaartuz
# City not found. Skipping...
# Processing Record 48 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 49 of Set 7 | buraydah
# Processing Record 0 of Set 8 | ramgarh
# Processing Record 1 of Set 8 | geghamasar
# Processing Record 2 of Set 8 | alofi
# Processing Record 3 of Set 8 | moroto
# Processing Record 4 of Set 8 | balaipungut
# Processing Record 5 of Set 8 | nicoya
# Processing Record 6 of Set 8 | barahona
# Processing Record 7 of Set 8 | mookane
# Processing Record 8 of Set 8 | chaudfontaine
# Processing Record 9 of Set 8 | codrington
# Processing Record 10 of Set 8 | nouakchott
# Processing Record 11 of Set 8 | bloomington
# Processing Record 12 of Set 8 | altay
# Processing Record 13 of Set 8 | cabo san lucas
# Processing Record 14 of Set 8 | warren
# Processing Record 15 of Set 8 | laramie
# Processing Record 16 of Set 8 | garowe
# Processing Record 17 of Set 8 | vila franca do campo
# Processing Record 18 of Set 8 | fort frances
# Processing Record 19 of Set 8 | anaco
# Processing Record 20 of Set 8 | camacha
# Processing Record 21 of Set 8 | bumba
# Processing Record 22 of Set 8 | mazagao
# Processing Record 23 of Set 8 | brainerd
# Processing Record 24 of Set 8 | rosarito
# Processing Record 25 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 8 | antalaha
# Processing Record 27 of Set 8 | riyadh
# Processing Record 28 of Set 8 | mendi
# Processing Record 29 of Set 8 | zhezkazgan
# Processing Record 30 of Set 8 | karlskoga
# Processing Record 31 of Set 8 | yerofey pavlovich
# Processing Record 32 of Set 8 | sungairaya
# Processing Record 33 of Set 8 | severo-kurilsk
# Processing Record 34 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 8 | luohe
# Processing Record 36 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 8 | morondava
# Processing Record 38 of Set 8 | san pedro
# Processing Record 39 of Set 8 | malanje
# Processing Record 40 of Set 8 | chikoy
# City not found. Skipping...
# Processing Record 41 of Set 8 | vardo
# Processing Record 42 of Set 8 | laguna
# Processing Record 43 of Set 8 | sao miguel do araguaia
# Processing Record 44 of Set 8 | camana
# Processing Record 45 of Set 8 | padang
# Processing Record 46 of Set 8 | ilinskiy
# Processing Record 47 of Set 8 | nabire
# Processing Record 48 of Set 8 | nuuk
# Processing Record 49 of Set 8 | stonewall
# Processing Record 0 of Set 9 | mashhad
# Processing Record 1 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 9 | carutapera
# Processing Record 3 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 9 | dunnville
# Processing Record 6 of Set 9 | amahai
# Processing Record 7 of Set 9 | zeya
# Processing Record 8 of Set 9 | lasa
# Processing Record 9 of Set 9 | pontes e lacerda
# Processing Record 10 of Set 9 | buin
# Processing Record 11 of Set 9 | kedrovyy
# Processing Record 12 of Set 9 | yagodnoye
# Processing Record 13 of Set 9 | mahibadhoo
# Processing Record 14 of Set 9 | aleppo
# Processing Record 15 of Set 9 | celestun
# Processing Record 16 of Set 9 | ystad
# Processing Record 17 of Set 9 | timiryazevskoye
# Processing Record 18 of Set 9 | salantai
# Processing Record 19 of Set 9 | warrington
# Processing Record 20 of Set 9 | springfield
# Processing Record 21 of Set 9 | makakilo city
# Processing Record 22 of Set 9 | pimenta bueno
# Processing Record 23 of Set 9 | elko
# Processing Record 24 of Set 9 | cockburn town
# Processing Record 25 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 9 | fortuna
# Processing Record 27 of Set 9 | jumla
# Processing Record 28 of Set 9 | guarulhos
# Processing Record 29 of Set 9 | biak
# Processing Record 30 of Set 9 | tolaga bay
# Processing Record 31 of Set 9 | bathsheba
# Processing Record 32 of Set 9 | wilmington
# Processing Record 33 of Set 9 | yenagoa
# Processing Record 34 of Set 9 | grand gaube
# Processing Record 35 of Set 9 | maun
# Processing Record 36 of Set 9 | dhidhdhoo
# Processing Record 37 of Set 9 | gorontalo
# Processing Record 38 of Set 9 | arica
# Processing Record 39 of Set 9 | groningen
# Processing Record 40 of Set 9 | port pirie
# Processing Record 41 of Set 9 | wuzhou
# Processing Record 42 of Set 9 | leavenworth
# Processing Record 43 of Set 9 | ascension
# Processing Record 44 of Set 9 | ouargaye
# Processing Record 45 of Set 9 | ningxiang
# Processing Record 46 of Set 9 | sisimiut
# Processing Record 47 of Set 9 | takoradi
# Processing Record 48 of Set 9 | oranjestad
# Processing Record 49 of Set 9 | tchollire
# Processing Record 0 of Set 10 | oshakati
# Processing Record 1 of Set 10 | camocim
# Processing Record 2 of Set 10 | rocha
# Processing Record 3 of Set 10 | touros
# Processing Record 4 of Set 10 | beira
# Processing Record 5 of Set 10 | calabozo
# Processing Record 6 of Set 10 | dalnerechensk
# Processing Record 7 of Set 10 | yarmouth
# Processing Record 8 of Set 10 | sungai siput utara
# City not found. Skipping...
# Processing Record 9 of Set 10 | lata
# Processing Record 10 of Set 10 | garden city
# Processing Record 11 of Set 10 | mirabad
# Processing Record 12 of Set 10 | beyneu
# Processing Record 13 of Set 10 | roebourne
# Processing Record 14 of Set 10 | dillon
# Processing Record 15 of Set 10 | nouadhibou
# Processing Record 16 of Set 10 | poum
# Processing Record 17 of Set 10 | chicama
# Processing Record 18 of Set 10 | oussouye
# Processing Record 19 of Set 10 | male
# Processing Record 20 of Set 10 | chara
# Processing Record 21 of Set 10 | tieli
# Processing Record 22 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 10 | mukhen
# Processing Record 24 of Set 10 | baherden
# Processing Record 25 of Set 10 | koungou
# Processing Record 26 of Set 10 | tigil
# Processing Record 27 of Set 10 | fallon
# Processing Record 28 of Set 10 | port hardy
# Processing Record 29 of Set 10 | kloulklubed
# Processing Record 30 of Set 10 | kirakira
# Processing Record 31 of Set 10 | inirida
# Processing Record 32 of Set 10 | bima
# Processing Record 33 of Set 10 | turan
# Processing Record 34 of Set 10 | la ronge
# Processing Record 35 of Set 10 | piraquara
# Processing Record 36 of Set 10 | iskateley
# Processing Record 37 of Set 10 | kalat
# Processing Record 38 of Set 10 | mandalgovi
# Processing Record 39 of Set 10 | kifri
# Processing Record 40 of Set 10 | bilma
# Processing Record 41 of Set 10 | santa catarina de tepehuanes
# Processing Record 42 of Set 10 | tabuk
# Processing Record 43 of Set 10 | beringovskiy
# Processing Record 44 of Set 10 | tari
# Processing Record 45 of Set 10 | kawalu
# Processing Record 46 of Set 10 | verkhnyaya inta
# Processing Record 47 of Set 10 | teya
# Processing Record 48 of Set 10 | eau claire
# Processing Record 49 of Set 10 | chilca
# Processing Record 0 of Set 11 | swan hill
# Processing Record 1 of Set 11 | svetlogorsk
# Processing Record 2 of Set 11 | olhao
# Processing Record 3 of Set 11 | kuala krai
# City not found. Skipping...
# Processing Record 4 of Set 11 | cruz
# Processing Record 5 of Set 11 | acarau
# Processing Record 6 of Set 11 | ayr
# Processing Record 7 of Set 11 | nome
# Processing Record 8 of Set 11 | nelson bay
# Processing Record 9 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 10 of Set 11 | acapulco
# Processing Record 11 of Set 11 | jahazpur
# Processing Record 12 of Set 11 | fraga
# Processing Record 13 of Set 11 | kishangarh
# Processing Record 14 of Set 11 | chaoyang
# Processing Record 15 of Set 11 | flinders
# Processing Record 16 of Set 11 | barguzin
# Processing Record 17 of Set 11 | oliveira dos brejinhos
# Processing Record 18 of Set 11 | sept-iles
# Processing Record 19 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 11 | port-gentil
# Processing Record 21 of Set 11 | pocatello
# Processing Record 22 of Set 11 | ambon
# Processing Record 23 of Set 11 | fairbanks
# Processing Record 24 of Set 11 | palmer
# Processing Record 25 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 11 | magadan
# Processing Record 27 of Set 11 | finschhafen
# Processing Record 28 of Set 11 | betong
# Processing Record 29 of Set 11 | zhengjiatun
# Processing Record 30 of Set 11 | ust-kuyga
# Processing Record 31 of Set 11 | yuanping
# Processing Record 32 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 33 of Set 11 | boa vista
# Processing Record 34 of Set 11 | terrace bay
# Processing Record 35 of Set 11 | zhigansk
# Processing Record 36 of Set 11 | mandla
# Processing Record 37 of Set 11 | bure
# Processing Record 38 of Set 11 | tezu
# Processing Record 39 of Set 11 | raudeberg
# Processing Record 40 of Set 11 | yellamanchili
# City not found. Skipping...
# Processing Record 41 of Set 11 | otavi
# Processing Record 42 of Set 11 | palmerston
# Processing Record 43 of Set 11 | abu samrah
# Processing Record 44 of Set 11 | boulder city
# Processing Record 45 of Set 11 | necochea
# Processing Record 46 of Set 11 | yeppoon
# Processing Record 47 of Set 11 | shahrud
# Processing Record 48 of Set 11 | lingao
# Processing Record 49 of Set 11 | tura
# Processing Record 0 of Set 12 | loralai
# Processing Record 1 of Set 12 | gonzales
# Processing Record 2 of Set 12 | nileshwar
# Processing Record 3 of Set 12 | svirstroy
# Processing Record 4 of Set 12 | rumuruti
# Processing Record 5 of Set 12 | visnes
# Processing Record 6 of Set 12 | ihosy
# Processing Record 7 of Set 12 | clyde river
# Processing Record 8 of Set 12 | labuhan
# Processing Record 9 of Set 12 | labuan
# Processing Record 10 of Set 12 | niksic
# Processing Record 11 of Set 12 | casper
# Processing Record 12 of Set 12 | southend-on-sea
# Processing Record 13 of Set 12 | kushima
# Processing Record 14 of Set 12 | emba
# Processing Record 15 of Set 12 | kaka
# Processing Record 16 of Set 12 | klichka
# Processing Record 17 of Set 12 | santa cruz
# Processing Record 18 of Set 12 | kilindoni
# Processing Record 19 of Set 12 | narasapur
# Processing Record 20 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 12 | kununurra
# Processing Record 22 of Set 12 | tsabong
# Processing Record 23 of Set 12 | bubaque
# Processing Record 24 of Set 12 | kungurtug
# Processing Record 25 of Set 12 | hearst
# Processing Record 26 of Set 12 | hami
# Processing Record 27 of Set 12 | dakar
# Processing Record 28 of Set 12 | nurota
# Processing Record 29 of Set 12 | hare bay
# Processing Record 30 of Set 12 | belmonte
# Processing Record 31 of Set 12 | lima
# Processing Record 32 of Set 12 | meybod
# Processing Record 33 of Set 12 | kpandu
# Processing Record 34 of Set 12 | nedjo
# Processing Record 35 of Set 12 | quatre cocos
# Processing Record 36 of Set 12 | pareora
# Processing Record 37 of Set 12 | coquimbo
# Processing Record 38 of Set 12 | tefe
# Processing Record 39 of Set 12 | trincomalee
# Processing Record 40 of Set 12 | lemesos
# City not found. Skipping...
# Processing Record 41 of Set 12 | arawa
# Processing Record 42 of Set 12 | bar harbor
# Processing Record 43 of Set 12 | tromso
# Processing Record 44 of Set 12 | royan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          542
# Lat           542
# Lng           542
# Max Temp      542
# Humidity      542
# Cloudiness    542
# Wind Speed    542
# Country       542
# Date          542
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  punta cardon  11.6581  -70.2150     82.89        65           0
# 1          hilo  19.7297 -155.0900     73.27        89         100
# 2       ushuaia -54.8000  -68.3000     62.26        39          20
# 3         korla  41.7597   86.1469     33.82        26          64
# 4         matay  28.4190   30.7792     75.52        12           0
#
#    Wind Speed Country        Date
# 0       27.81      VE  1680546254
# 1        5.75      US  1680546187
# 2       10.36      AR  1680546045
# 3        9.82      CN  1680546255
# 4        7.83      EG  1680546255

# %%
# Export the City_Data into a csv
city_data_df.to_csv("/Users/nels.jacobson2/Desktop/Analytics_Class_Folder/040323_Challenge/python-api-challenge/Starter_Code_April_3/output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("/Users/nels.jacobson2/Desktop/Analytics_Class_Folder/040323_Challenge/python-api-challenge/Starter_Code_April_3/output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        punta cardon  11.6581  -70.2150     82.89        65           0
# 1                hilo  19.7297 -155.0900     73.27        89         100
# 2             ushuaia -54.8000  -68.3000     62.26        39          20
# 3               korla  41.7597   86.1469     33.82        26          64
# 4               matay  28.4190   30.7792     75.52        12           0
#
#          Wind Speed Country        Date
# City_ID
# 0             27.81      VE  1680546254
# 1              5.75      US  1680546187
# 2             10.36      AR  1680546045
# 3              9.82      CN  1680546255
# 4              7.83      EG  1680546255

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

# Save the figure
plt.savefig("/Users/nels.jacobson2/Desktop/Analytics_Class_Folder/040323_Challenge/python-api-challenge/Starter_Code_April_3/output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolors="black", alpha=0.8)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (04/03/2023)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.xlim(-60, 80)
plt.ylim(0, 110)
plt.grid(True)

# Save the figure
plt.savefig("/Users/nels.jacobson2/Desktop/Analytics_Class_Folder/040323_Challenge/python-api-challenge/Starter_Code_April_3/output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (04/03/2023)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.xlim(-60, 90)
plt.ylim(-5, 105)
plt.grid(True)

# Save the figure
plt.savefig("/Users/nels.jacobson2/Desktop/Analytics_Class_Folder/040323_Challenge/python-api-challenge/Starter_Code_April_3/output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (04/03/2023)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s")
plt.grid(True)

# Save the figure
plt.savefig("/Users/nels.jacobson2/Desktop/Analytics_Class_Folder/040323_Challenge/python-api-challenge/Starter_Code_April_3/output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates, ylabel):
    # Perform linear regression
    slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
    # Create equation of line
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,slope*x_values+intercept,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(ylabel)
    plt.title(title)
    print(f"The r-value is: {rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        punta cardon  11.6581  -70.2150     82.89        65           0
# 1                hilo  19.7297 -155.0900     73.27        89         100
# 3               korla  41.7597   86.1469     33.82        26          64
# 4               matay  28.4190   30.7792     75.52        12           0
# 5                 fez  34.0372   -4.9998     73.65        40           0
#
#          Wind Speed Country        Date
# City_ID
# 0             27.81      VE  1680546254
# 1              5.75      US  1680546187
# 3              9.82      CN  1680546255
# 4              7.83      EG  1680546255
# 5             12.66      MA  1680546078

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2           ushuaia -54.8000  -68.3000     62.26        39          20
# 6         busselton -33.6500  115.3333     57.42        86           2
# 12             lebu -37.6167  -73.6500     59.13        64           0
# 13       bredasdorp -34.5322   20.0403     63.03        75          88
# 22          rikitea -23.1203 -134.9692     79.77        82          80
#
#          Wind Speed Country        Date
# City_ID
# 2             10.36      AR  1680546045
# 6              5.84      AU  1680546263
# 12            18.34      CL  1680546272
# 13             5.10      ZA  1680545984
# 22            13.13      PF  1680546141

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], "Max Temp (F) vs. Latitude Linear Regression (Northern Hemisphere)", (0,0), "Max Temp")
# Out:
# The r-value is: -0.8766720621831903

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], "Max Temp (F) vs. Latitude Linear Regression (Southern Hemisphere)", (0,0), "Max Temp")
# Out:
# The r-value is: 0.6996887024060182

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], "Humidity vs. Latitude Linear Regression (Northern Hemisphere)", (0,0), "Humidity")
# Out:
# The r-value is: 0.3256198301495529

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], "Humidity vs. Latitude Linear Regression (Southern Hemisphere)", (0,0), "Humidity")
# Out:
# The r-value is: 0.23275305648440175

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], "Cloudiness vs. Latitude Linear Regression (Northern Hemisphere)", (0,0), "Cloudiness")
# Out:
# The r-value is: 0.09651231255251166

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], "Cloudiness vs. Latitude Linear Regression (Southern Hemisphere)", (0,0), "Cloudiness")
# Out:
# The r-value is: 0.2715071579655539

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], "Wind Speed vs. Latitude Linear Regression (Northern Hemisphere)", (0,0), "Wind Speed")
# Out:
# The r-value is: 0.0725721536672095

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], "Wind Speed vs. Latitude Linear Regression (Southern Hemisphere)", (0,0), "Wind Speed")
# Out:
# The r-value is: -0.26023842414207277

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
